# %%
# %matplotlib notebook
import matplotlib.pyplot as pl
import numpy as np
from astropy.io import fits

# %%
im = fits.open("./from_monika/D00145430_z_c01_r4148p01_immasked.fits.fz")
f = fits.open("./from_monika/D00145430_z_c01_r4148p01_psfex-starlist.fits")

# %%
x = f[2].data['x_image'].astype(int)
y = f[2].data['y_image'].astype(int)

# %%
goodstars= np.where(f[2].data['flags_psf']==0)[0]

# %%
goodstars.shape
# Out:
# (127,)

# %%
box=10
N=100
count=0
fig, axs = pl.subplots(10,10,figsize=(50,50))
for coords in zip(x[goodstars][0:N],y[goodstars][0:N]):
    print(coords)
    cutout = im['sci'].data[ coords[1]-box:coords[1]+box , coords[0]-box:coords[0]+box ]
    axs.flatten()[count].imshow(cutout)
    axs.flatten()[count].set_xticks([])
    axs.flatten()[count].set_yticks([])
    count=count+1
pl.tight_layout()
pl.savefig('./test2.pdf')
# Out:
# <img src="data:image/png;base64,..." width="5000">
# (1664, 73)
# (967, 81)
# (1756, 215)
# (1726, 261)
# (1636, 300)
# (1252, 315)
# (173, 376)
# (1239, 511)
# (1284, 514)
# (1293, 529)
# (1711, 531)
# (1868, 561)
# (1558, 584)
# (1238, 623)
# (1563, 629)
# (1596, 663)
# (1148, 724)
# (1405, 766)
# (1485, 798)
# (383, 821)
# (1132, 834)
# (723, 875)
# (568, 913)
# (1329, 987)
# (1659, 998)
# (1401, 1021)
# (1968, 1025)
# (1247, 1046)
# (1284, 1087)
# (1498, 1084)
# (557, 1113)
# (1351, 1118)
# (409, 1155)
# (1033, 1187)
# (444, 1202)
# (1799, 1216)
# (1378, 1252)
# (1564, 1327)
# (1156, 1332)
# (432, 1381)
# (760, 1364)
# (1100, 1372)
# (1409, 1385)
# (449, 1429)
# (549, 1467)
# (441, 1470)
# (1930, 1528)
# (156, 1531)
# (492, 1535)
# (1195, 1543)
# (135, 1544)
# (1996, 1545)
# (1193, 1575)
# (399, 1583)
# (231, 1588)
# (447, 1706)
# (968, 1782)
# (1174, 1843)
# (1728, 1921)
# (1017, 1928)
# (1550, 1985)
# (1232, 2031)
# (638, 2063)
# (457, 2096)
# (745, 2148)
# (490, 2156)
# ...

# %%
f.info()
# Out:
# Filename: ./from_monika/D00145430_z_c01_r4148p01_psfex-starlist.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      17   ()
#   1  LDAC_IMHEAD    1 BinTableHDU     12   1R x 1C   [560A]
#   2  LDAC_OBJECTS    1 BinTableHDU     60   441R x 15C   [1J, 1I, 1J, 1J, 2D, 1D, 1D, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E]

# %%
f[2].header
# Out:
# XTENSION= 'BINTABLE'           / THIS IS A BINARY TABLE (FROM THE LDACTOOLS)
# BITPIX  =                    8 /
# NAXIS   =                    2 /
# NAXIS1  =                   78 / BYTES PER ROW
# NAXIS2  =                  441 / NUMBER OF ROWS
# PCOUNT  =                    0 / RANDOM PARAMETER COUNT
# GCOUNT  =                    1 / GROUP COUNT
# TFIELDS =                   15 / FIELDS PER ROWS
# EXTNAME = 'LDAC_OBJECTS'       / TABLE NAME
# TTYPE1  = 'SOURCE_NUMBER'      / Source index
# TFORM1  = '1J      '
# TDISP1  = 'I10     '
# TTYPE2  = 'EXTENSION'          / Extension index
# TFORM2  = '1I      '
# TDISP2  = 'I4      '
# TTYPE3  = 'CATALOG_NUMBER'     / File index
# TFORM3  = '1J      '
# TDISP3  = 'I7      '
# TTYPE4  = 'FLAGS_PSF'          / PSFEx rejection flags
# TFORM4  = '1J      '
# TDISP4  = 'I7      '
# TTYPE5  = 'VECTOR_CONTEXT'     / Context vector
# TFORM5  = '2D      '
# TDISP5  = 'G12.6   '
# TTYPE6  = 'X_IMAGE '           / Position along x image axis
# ...
